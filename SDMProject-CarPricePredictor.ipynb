# %%
import pandas as pd

# %%
##Load the dataset
df=pd.read_csv('car data.csv')

# %%
##Print first five records of the dataset 
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
##Print the number of rows and columns in the dataset
df.shape
# Out:
# (301, 9)

# %%
##find the categorical variables 
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
##check missing or null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
##Create a final dataset variable to store everything except the car name.
final_dataset = df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
#Lets do some feature engineering create a new column with the current year.
final_dataset['Current_year']=2020

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
#Subtract the current year feature and the year feature to find the number of years to calculate depreciation in price.
final_dataset['no_year'] = final_dataset['Current_year']-final_dataset['Year']

# %%
##Drop the year column as its job is done
final_dataset.drop(['Year'], axis=1, inplace=True)

# %%
##Drop the current year column as its job is done
final_dataset.drop(['Current_year'], axis=1, inplace=True)

# %%
##year and current year columns deleted yayy
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_year
# 0       Manual      0        6
# 1       Manual      0        7
# 2       Manual      0        3
# 3       Manual      0        9
# 4       Manual      0        6

# %%
##One hot encode the categorical variables and drop the dummy variables.
final_dataset =  pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0        6                 0
# 1           4.75           9.54       43000      0        7                 1
# 2           7.25           9.85        6900      0        3                 0
# 3           2.85           4.15        5200      0        9                 0
# 4           4.60           6.87       42450      0        6                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                          no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
#Independent and dependent features
X=final_dataset.iloc[:,1:] #Independent
Y=final_dataset.iloc[:,0] #dependent

# %%
#Fit model to data using a external trees regressor as this is a regression problem.
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
#Print the feature importances these values change everytime model is fitted to the data.
print(model.feature_importances_)
# Out:
# [0.40839603 0.04110353 0.00059273 0.07707922 0.20594932 0.0222064
#  0.116762   0.12791077]

# %%
#Split data into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
#      Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 101           1.82        1400      0        3                 0
# 80           14.89       23000      0        4                 1
# 274           6.80       16500      0        6                 0
# 105           2.37       21700      0        5                 0
# 278           8.40        4000      0        4                 0
# ..             ...         ...    ...      ...               ...
# 117           1.90       14000      0        5                 0
# 279          13.60       40126      0        6                 0
# 163           0.95       27000      0       10                 0
# 62           35.96       78000      0        6                 1
# 106           3.45       16500      1        6                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 101                 1                       1                    1
# ...

# %%
X_train.shape
# Out:
# (240, 8)

# %%
#implementing random forest regressor as it will make our lives easier because we don't have to normalize data
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
##Tuning those hyperparameters babyyyyy
import numpy as np
#generate different number of trees using a numpy linear space with 12 samples
n_estimators = [int(x) for x in np.linspace(start=100, stop=1200, num=12)]
#Number of features to consider at every split
max_features=['auto','sqrt']
#generate different levels of depth for the trees using linear space
max_depth = [int(x) for x in np.linspace(5,30,num=6)]
#minimum number of samples required to split a node
min_samples_split = [2,5,10,15,100]
#minimum number of samples required at each leaf node
min_samples_leaf = [1,2,5,10]

# %%
#Now use all those parameter values to perform different permutations of training and get the best parameter values
from sklearn.model_selection import RandomizedSearchCV
random_grid = {'n_estimators':n_estimators,
               'max_features':max_features,
               'max_depth':max_depth,
               'min_samples_split':min_samples_split,
               'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
#final step train the model using everything until now.
#initialise the randome forest regressor
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=1)

# %%
#finally train it on the training set
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.4s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
#model has been trained now time for predictions on the test set
predictions = rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 0.94798,  2.77943,  5.4695 ,  6.61446,  9.22231,  3.0288 ,
#         0.77707,  2.35783,  0.46021,  3.23121,  0.39071,  4.50527,
#         7.68936,  5.26334,  1.11637,  0.6161 ,  5.74081,  9.22238,
#         6.1885 ,  4.68255,  5.05944,  3.8969 ,  8.14073,  6.02612,
#         4.06946,  4.14795, 13.45493,  7.7456 ,  0.96241, 21.30024,
#         0.5958 ,  7.5541 ,  8.4899 ,  2.36749,  0.43429,  3.57051,
#         2.70149,  9.86714,  0.61359,  8.34402,  3.57471,  5.51132,
#         4.31945,  4.98947,  0.89835,  7.19808,  2.68145,  0.70355,
#         0.79817,  5.12441,  8.08241,  4.38525,  0.47226,  7.57604,
#         0.62592,  5.29141,  3.24426, 10.6918 ,  0.55843,  0.76907,
#         0.82187])

# %%
#lets pickle up the model and use it for end to end applications.
import pickle
#make a pickle file in write binary mode.
file = open('random_forest_regression_model.pkl','wb')
#dump the model information in this pickle file
pickle.dump(rf_random,file)
